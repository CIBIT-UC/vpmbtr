# %% [markdown]
# sometimes we need to run the installer inside a notebook... no idea why

# %%
# !pip install -e .
# Out:
# Obtaining file:///DATAPOOL/home/alexandresayal/GitRepos/vpmb-tr
#   Preparing metadata (setup.py) ... done
# ...
#   Running setup.py develop for src
# ...
